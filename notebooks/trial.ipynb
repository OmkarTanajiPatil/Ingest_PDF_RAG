# %%
from google import genai
import dotenv
import os

dotenv.load_dotenv()

client = genai.Client(
    api_key=os.getenv("GEMINI_API_KEY")
)

response = client.models.generate_content(
    model="gemma-4-31b-it",
    contents="Hello"
)


print(response.text)
# Out:
# Hello! How can I help you today?

# %%
from google import genai
from google.genai import types
import os
from dotenv import load_dotenv

load_dotenv()

def rag_query_pdf_ai(question):
    

    user_content = (
        f"Question: {question}\n"
    )
    
    def _call_llm(client, content):
        print("Calling Gemini...")

        response = client.models.generate_content(
            model="gemma-4-31b-it",
            contents=content,
            # config=types.GenerateContentConfig(
            #     temperature=0.7,
            #     max_output_tokens=1000,
            # )
        )

        print("Gemini replied")

        return {
            "answer": response.text,
        }

    client = genai.Client(
        api_key=os.getenv("GEMINI_API_KEY")
    )
    
    res = _call_llm(client, user_content)
    return res
    
rag_query_pdf_ai("What is your name ?")
# Out:
# Calling Gemini...
# Gemini replied
# {'answer': 'I do not have a name. I am a large language model, trained by Google.'}

# %%
# Out:
# Calling Gemini...
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 rag_query_pdf_ai("What is your name ?")
#
# Cell In[13], line 34, in rag_query_pdf_ai(question)
#      30     client = genai.Client(
#      31         api_key=os.getenv("GEMINI_API_KEY")
#      32     )
#      33
# ---> 34     res = _call_llm(client, user_content)
#      35     return res
#
# Cell In[13], line 15, in rag_query_pdf_ai.<locals>._call_llm(client, content)
#      12     def _call_llm(client, content):
#      13         print("Calling Gemini...")
#      14
# ---> 15         response = client.models.generate_content(
#      16             model="gemini-2.0-flash-lite",
#      17             contents=content,
#      18             # config=types.GenerateContentConfig(
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\models.py:6480, in Models.generate_content(self, model, contents, config)
#    6478 while remaining_remote_calls_afc > 0:
#    6479   i += 1
# -> 6480   response = self._generate_content(
#    6481       model=model, contents=contents, config=parsed_config
#    6482   )
#    6484   function_map = _extra_utils.get_function_map(parsed_config)
#    6485   if not function_map:
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\models.py:4916, in Models._generate_content(self, model, contents, config)
#    4913 request_dict = _common.convert_to_dict(request_dict)
#    4914 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4916 response = self._api_client.request(
#    4917     'post', path, request_dict, http_options
#    4918 )
#    4920 if config is not None and getattr(
#    4921     config, 'should_return_http_response', None
#    4922 ):
#    4923   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\_api_client.py:1611, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1601 def request(
#    1602     self,
#    1603     http_method: str,
#    (...)   1606     http_options: Optional[HttpOptionsOrDict] = None,
#    1607 ) -> SdkHttpResponse:
#    1608   http_request = self._build_request(
#    1609       http_method, path, request_dict, http_options
#    1610   )
# -> 1611   response = self._request(http_request, http_options, stream=False)
#    1612   response_body = (
#    1613       response.response_stream[0] if response.response_stream else ''
#    1614   )
#    1615   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\_api_client.py:1404, in BaseApiClient._request(self, http_request, http_options, stream)
#    1401     retry = tenacity.Retrying(**retry_kwargs)
#    1402     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1404 return self._retry(self._request_once, http_request, stream)
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\_api_client.py:1381, in BaseApiClient._request_once(self, http_request, stream)
#    1373   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1374       method=http_request.method,
#    1375       url=http_request.url,
#    (...)   1378       timeout=http_request.timeout,
#    1379   )
#    1380   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1381 errors.APIError.raise_for_response(response)
#    1382 return HttpResponse(
#    1383     response.headers, response if stream else [response.text]
#    1384 )
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File e:\PROJECTS\First_Rag_Application\.venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     170 """Raises an appropriate APIError subclass based on the status code.
#     171
#     172 Args:
#    (...)    181   APIError: For other error status codes.
#     182 """
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#     186   raise ServerError(status_code, response_json, response)
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 0, model: gemini-2.0-flash-lite\n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_input_token_count, limit: 0, model: gemini-2.0-flash-lite\nPlease retry in 16.978875897s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-2.0-flash-lite', 'location': 'global'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.0-flash-lite'}}, {'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_input_token_count', 'quotaId': 'GenerateContentInputTokensPerModelPerMinute-FreeTier', 'quotaDimensions': {'model': 'gemini-2.0-flash-lite', 'location': 'global'}}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '16s'}]}}
